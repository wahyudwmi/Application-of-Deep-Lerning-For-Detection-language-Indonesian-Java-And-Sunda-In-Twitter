# %%
#https://gist.github.com/yanofsky/5436496
#!/usr/bin/env python
# encoding: utf-8
#https://github.com/tweepy/tweepy

import tweepy
import csv
from tweepy import OAuthHandler, Stream, StreamListener

#Twitter API credentials
consumer_key = "I0E7xGaPsVIIyg0sq8tfw"
consumer_secret = "frk7rjhTVHEuRErf4V2h93xZ6eSAr2myy9gH4RaU"
access_key = "228245421-FPyC4SFufgkHDmHy7gTpEqm36mbFepYmkQ2p54xf"
access_secret = "cYc2xsbeKiTAlb8RuQ9btHZxERGNoFrlazKBPTnQ"

# %%
def get_all_tweets(screen_name): 
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
    alltweets = []

    new_tweets = api.user_timeline(screen_name = screen_name,count=200, tweet_mode="extended")

    alltweets.extend(new_tweets)
    oldest = alltweets[-1].id - 1
    while len(new_tweets) > 0:
        print("getting tweets before %s" % (oldest))
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest, tweet_mode="extended")
        alltweets.extend(new_tweets)
        oldest = alltweets[-1].id - 1
        print("...%s tweets downloaded so far" % (len(alltweets)))

    outtweets = [[tweet.id_str, tweet.created_at, tweet.full_text.encode("utf-8")] for tweet in alltweets]
    with open('%s_tweets.csv' % screen_name, 'w') as f:
        writer = csv.writer(f)
        writer.writerow(["id","created_at","text"])
        writer.writerows(outtweets)
    pass

# %%
if __name__ == '__main__':
    account = ['@Moektito'] #add account twitter

    for acc in account:
        get_all_tweets(acc)
# Out:
# getting tweets before 967428716329541631
# ...368 tweets downloaded so far
# getting tweets before 928232465545641983
# ...566 tweets downloaded so far
# getting tweets before 875374652909944832
# ...763 tweets downloaded so far
# getting tweets before 845902200253509632
# ...963 tweets downloaded so far
# getting tweets before 811570381597249536
# ...1156 tweets downloaded so far
# getting tweets before 788937839413108735
# ...1354 tweets downloaded so far
# getting tweets before 763627701349470207
# ...1548 tweets downloaded so far
# getting tweets before 750272159994376191
# ...1740 tweets downloaded so far
# getting tweets before 740857444880912385
# ...1937 tweets downloaded so far
# getting tweets before 725691851638874111
# ...2132 tweets downloaded so far
# getting tweets before 719148151030947841
# ...2320 tweets downloaded so far
# getting tweets before 715502002554298367
# ...2509 tweets downloaded so far
# getting tweets before 705615810581000191
# ...2699 tweets downloaded so far
# getting tweets before 695474018829209599
# ...2887 tweets downloaded so far
# getting tweets before 677058368205287423
# ...2986 tweets downloaded so far
# getting tweets before 670206307392094208
# ...2986 tweets downloaded so far

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
